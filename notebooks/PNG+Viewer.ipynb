# %%
import zipfile

# %%
ls /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngsTestFinal_4
# Out:
# testset_10.zip  testset_26.zip  testset_41.zip  testset_57.zip  testset_72.zip
# testset_11.zip  testset_27.zip  testset_42.zip  testset_58.zip  testset_73.zip
# testset_12.zip  testset_28.zip  testset_43.zip  testset_59.zip  testset_74.zip
# testset_13.zip  testset_29.zip  testset_44.zip  testset_5.zip   testset_75.zip
# testset_14.zip  testset_2.zip   testset_45.zip  testset_60.zip  testset_76.zip
# testset_15.zip  testset_30.zip  testset_46.zip  testset_61.zip  testset_77.zip
# testset_16.zip  testset_31.zip  testset_47.zip  testset_62.zip  testset_78.zip
# testset_17.zip  testset_32.zip  testset_48.zip  testset_63.zip  testset_79.zip
# testset_18.zip  testset_33.zip  testset_49.zip  testset_64.zip  testset_7.zip
# testset_19.zip  testset_34.zip  testset_4.zip   testset_65.zip  testset_80.zip
# testset_1.zip   testset_35.zip  testset_50.zip  testset_66.zip  testset_81.zip
# testset_20.zip  testset_36.zip  testset_51.zip  testset_67.zip  testset_8.zip
# ...

# %%
zz = zipfile.ZipFile('/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngsTestFinal_4/testset_75.zip')
test_list = zz.namelist()
randomSignal = zz.open(test_list[1],'r')

# %%
# ls Machine_Contact_Enterprise_SETI/cleanPngsTest/

# %%
from IPython.display import Image
f = open("./Machine_Contact_Enterprise_SETI/cleanPngsTest/0b6b49d7-9f7a-4773-8436-691de92d6828.dat.png").read()
Image(f)

# %%
from IPython.display import Image
squigImg = randomSignal.read()
Image(squigImg)
