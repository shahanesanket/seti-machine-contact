# %% [markdown]
# # Watson Visual Recognition Training with Spectrogram Images from SETI Signal Data
#
# * https://www.ibm.com/watson/developercloud/visual-recognition/api/v3/
# * https://www.ibm.com/watson/developercloud/doc/visual-recognition/customizing.html
# * https://github.com/watson-developer-cloud/python-sdk
# * https://github.com/watson-developer-cloud/python-sdk/blob/master/watson_developer_cloud/visual_recognition_v3.py
#
# <hr>
#
# ## Install the Watson Developer Cloud Python SDK
#
# * Install the Python SDK if has not been previously installed **`!pip install --upgrade watson-developer-cloud`**
# * Restart the kernel, after installing the SDK

# %%
#!pip install --user --upgrade watson-developer-cloud

# %%
#Making a local folder to put my data.

### SET YOUR TEAM NAME HERE! Use this folder to save intermediate results
teamname = "Machine_Contact_Enterprise_SETI"

mydatafolder = os.path.join( os.environ['PWD'], teamname )  
if os.path.exists(mydatafolder) is False:
    raise Exception('This folder needs to already exist. See the Build_And_Package_Spectrograms_HackathonSpark notebook')
    

    
zipfilefolder = mydatafolder + '/zippedPngs3'
if os.path.exists(zipfilefolder) is False:
    raise Exception('This folder needs to already exist. See the Build_And_Package_Spectrograms_HackathonSpark notebook')

# %%
from watson_developer_cloud import VisualRecognitionV3
apiVer = VisualRecognitionV3.latest_version #'2016-05-20'
classifier_prefix = teamname + "_v1_"

#You can sign up with WatsonVR through Bluemix to get a key
#However, Hackathon participants will be provided with a WATSON VR key that has more free API calls per day.
apiKey = 'c70486e04c0e6ac12314da71f2fdb88992420c33'

# %%
# @hidden_cell
# apiKey = ''

# %%
#!ls -lah $mydatafolder/zippedPngs

# %%
from __future__ import division

import cStringIO
import glob
import json
import os
import requests
import time
import timeit
import zipfile
import copy

from random import randint

import matplotlib.pyplot as plt
import numpy as np

import ibmseti

import re

# %% [markdown]
# <br/>
# ## Init the Watson Visual Recognition Python Library
#
# * you may need to install the SDK first: **`!pip install --upgrade watson-developer-cloud`**
# * you will need the **API** key from the Watson Visual Recognition Service

# %%
vr = VisualRecognitionV3(apiVer, api_key=apiKey)

# %% [markdown]
# ## WARNING: This next cell will delete custom classifiers
# # DO NOT DELETE OTHER TEAM'S CLASSIFIERS.

# %%
## Run this cell ONLY IF you want to REMOVE your classifiers
# Otherwise, the subsequent cell will append images to the `classifier_prefix` classifier

## You can run this code below. It will delete a custom classifer that startswith your 'classifier_prefix', which is
#    based on your teamname. 

# You can uncomment and run this code, but do NOT modify it. 

# If you have problems deleting your classifer, talk to an IBMer

# classifiers = vr.list_classifiers()
# for c in classifiers['classifiers']:
#     if c['classifier_id'].startswith(classifier_prefix):
#         vr.delete_classifier(c['classifier_id'])

# %% [markdown]
# <br/>
# ## Look For Existing Custom Classifier
# Use an existing custom classifier (and update) if one exists, else a new custom classifier will be created

# %%
classifier_id = None
classifier = None

classifiers = vr.list_classifiers()

for c in classifiers['classifiers']:
    if c['status'] == 'ready' and (classifier_prefix in c['classifier_id']):
        classifier_id = c['classifier_id']


if classifier_id is not None:
    classifier = vr.get_classifier(classifier_id)
    print '\r\nFound classifer:\r\n\r\n{}'.format(json.dumps(classifier, indent=2))
else:
    print 'No custom classifier available\r\n'
    print(json.dumps(classifiers, indent=2))
# Out:
# No custom classifier available
#
# {
#   "classifiers": [
#     {
#       "status": "ready",
#       "classifier_id": "setisignals_570518428",
#       "name": "setisignals"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "feedo_elwin_v2__830874962",
#       "name": "feedo_elwin_v2_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "Machine_Contact_Enterprise_SET_549328565",
#       "name": "Machine_Contact_Enterprise_SETI_v1_"
#     },
#     {
#       "status": "training",
#       "classifier_id": "benders_v1__1257860168",
#       "name": "benders_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "Machine_Contact_Enterprise_SET_100417127",
#       "name": "Machine_Contact_Enterprise_SETI_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "team_magicai_v1_hanning_subnoi_1960338433",
#       "name": "team_magicai_v1_hanning_subnoise"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "feedo_elwin_v1__1756785049",
#       "name": "feedo_elwin_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "team_magicai_v1_hanning_83924230",
#       "name": "team_magicai_v1_hanning"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "somesnow_v1__1209090150",
#       "name": "somesnow_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "SpinFlip_v1__348338520",
#       "name": "SpinFlip_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "team_magicai_v1_hanning_1017759471",
#       "name": "team_magicai_v1_hanning"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "Machine_Contact_Enterprise_SET_1466269118",
#       "name": "Machine_Contact_Enterprise_SETI_v1_"
#     },
#     {
#       "status": "ready",
#       "classifier_id": "Machine_Contact_Enterprise_SET_842846996",
#       "name": "Machine_Contact_Enterprise_SETI_v1_"
#     }
#   ]
# }

# %% [markdown]
# <br/>
# ## Send the Images Archives to the Watson Visual Recognition Service for Training
#
# * https://www.ibm.com/watson/developercloud/doc/visual-recognition/customizing.html
# * https://www.ibm.com/watson/developercloud/visual-recognition/api/v3/
# * https://github.com/watson-developer-cloud/python-sdk

# %%
squiggle = sorted(glob.glob('{}/classification_*_squiggle.zip'.format(zipfilefolder)))
narrowband = sorted(glob.glob('{}/classification_*_narrowband.zip'.format(zipfilefolder)))
narrowbanddrd = sorted(glob.glob('{}/classification_*_narrowbanddrd.zip'.format(zipfilefolder)))
noise = sorted(glob.glob('{}/classification_*_noise.zip'.format(zipfilefolder)))
#brightpixel = sorted(glob.glob('{}/classification_*_brightpixel.zip'.format(zipfilefolder)))
#squarepulsednarrowband = sorted(glob.glob('{}/classification_*_squarepulsednarrowband.zip'.format(zipfilefolder)))
#squigglesquarepulsednarrowband = sorted(glob.glob('{}/classification_*_squigglesquarepulsednarrowband.zip'.format(zipfilefolder)))

sq = len(squiggle)
nb = len(narrowband)
nd = len(narrowbanddrd)
ns = len(noise)
#nbp = len(brightpixel)
#nsp = len(squarepulsednarrowband)
#nss = len(squigglesquarepulsednarrowband)

## Possible todo here: Try using the 'noise' as a "negative" example when training Watson. See the Watson documentation.

## for prototyping. 
num = 2
#num = max(sq, nb, nd, ns)


if classifier_id is None:
    print 'Adding custom classifier ... this may take awhile'
else:
    print 'Updating custom classifier {} ... this may take awhile'.format(classifier_id)

for i in range(num):
    squiggle_p = open(squiggle[i], 'rb') if i < sq else None
    narrowband_p = open(narrowband[i], 'rb') if i < nb else None
    narrowbanddrd_p = open(narrowbanddrd[i], 'rb') if i < nd else None
    noise_p = open(noise[i], 'rb') if i < ns else None
    #brightpixel_p = open(brightpixel[i], 'rb') if i < nb else None
    #squarepulsednarrowband_p = open(squarepulsednarrowband[i], 'rb') if i < nd else None
    #squigglesquarepulsednarrowband_p = open(squigglesquarepulsednarrowband[i], 'rb') if i < ns else None
    

    if classifier_id is None:
        print 'Creating new classifier. Batch {}'.format(i)
        classifier = vr.create_classifier(
            classifier_prefix,
            squiggle_positive_examples = squiggle_p,
            narrowband_positive_examples = narrowband_p,
            narrowbanddrd_positive_examples = narrowbanddrd_p,
            noise_positive_examples = noise_p
            #brightpixel_positive_examples = brightpixel_p,
            #squarepulsednarrowband_positive_examples = squarepulsednarrowband_p,
            #squigglesquarepulsednarrowband_positive_examples = squigglesquarepulsednarrowband_p
        )
        
        classifier_id = classifier['classifier_id']
    else:
        print 'Updating classifier. Batch {}'.format(i)
        classifier = vr.update_classifier(
            classifier_id,
            squiggle_positive_examples = squiggle_p,
            narrowband_positive_examples = narrowband_p,
            narrowbanddrd_positive_examples = narrowbanddrd_p,
            noise_positive_examples = noise_p
            #brightpixel_positive_examples = brightpixel_p,
            #squarepulsednarrowband_positive_examples = squarepulsednarrowband_p,
            #squigglesquarepulsednarrowband_positive_examples = squigglesquarepulsednarrowband_p 
        )

    if squiggle_p is not None:
        squiggle_p.close()
    if narrowband_p is not None:
        narrowband_p.close()
    if narrowbanddrd_p is not None:
        narrowbanddrd_p.close()
    if noise_p is not None:
        noise_p.close()
    #if brightpixel_p is not None:
    #    brightpixel_p.close()
    #if squarepulsednarrowband_p is not None:
    #    squarepulsednarrowband_p.close()
    #if squigglesquarepulsednarrowband_p is not None:
    #    squigglesquarepulsednarrowband_p.close()

    if classifier is not None:
        print('Classifier: {}'.format(classifier_id))
        status = classifier['status']
        startTimer = timeit.default_timer()
        while status in ['training', 'retraining']:
            print('Status: {}'.format(status))
            time.sleep(10)
            classifier = vr.get_classifier(classifier_id)
            status = classifier['status']
        stopTimer = timeit.default_timer()
        print '{} took {} minutes'.format('Training' if i == 0 else 'Retraining', int(stopTimer - startTimer) / 60)

print(json.dumps(vr.get_classifier(classifier_id), indent=2))
# Out:
# Adding custom classifier ... this may take awhile
# Creating new classifier. Batch 0
# Classifier: Machine_Contact_Enterprise_SET_778931065
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Status: training
# Training took 5.5 minutes
# Updating classifier. Batch 1
# Classifier: Machine_Contact_Enterprise_SET_778931065
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Status: retraining
# Retraining took 5.85 minutes
# {
#   "status": "ready",
#   "name": "Machine_Contact_Enterprise_SETI_v1_",
#   "created": "2017-06-11T04:01:02.485Z",
#   "retrained": "2017-06-11T04:09:39.789Z",
#   "classes": [
#     {
#       "class": "noise"
#     },
#     {
#       "class": "squiggle"
#     },
#     {
#       "class": "narrowbanddrd"
#     },
#     {
#       "class": "narrowband"
#     }
#   ],
#   "owner": "f770c2b8-6772-4a9e-a152-400b659eae58",
#   "classifier_id": "Machine_Contact_Enterprise_SET_778931065"
# }

# %% [markdown]
# <br/>
# ## Take a Random Data File for Testing
#
# * Take a random data file from the test set
# * Create a Spectrogram Image

# %%
# ls Machine_Contact_Enterprise_SETI/zippedPngs/

# %%
zz = zipfile.ZipFile('Machine_Contact_Enterprise_SETI/zippedPngs' + '/' + 'testset_1_narrowband.zip')

# %%
test_list = zz.namelist()
randomSignal = zz.open(test_list[4],'r')

# %%
# ls Machine_Contact_Enterprise_SETI/cleanPngs2/

# %%
# from IPython.display import Image
# f = open("./Machine_Contact_Enterprise_SETI/cleanPngs2/000919a5-bc7f-471e-959c-81adba0b1f36.dat.png").read()
# Image(f)

# %%
from IPython.display import Image
squigImg = randomSignal.read()
Image(squigImg)

# %%
#note - have to 'open' this again because it was already .read() out in the line above
randomSignal = zz.open(test_list[10],'r')

url_result = vr.classify(images_file=randomSignal, classifier_ids=classifier_id, threshold=0.0)

print(json.dumps(url_result, indent=2))
# Out:
# {
#   "images": [
#     {
#       "image": "gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/cleanPngs/061ae647-85b5-4891-b9a4-e67ae7776fa2.dat.png",
#       "classifiers": [
#         {
#           "classes": [
#             {
#               "score": 0.0357723,
#               "class": "narrowband"
#             },
#             {
#               "score": 0.228047,
#               "class": "narrowbanddrd"
#             },
#             {
#               "score": 0.383742,
#               "class": "noise"
#             },
#             {
#               "score": 0.20006,
#               "class": "squiggle"
#             }
#           ],
#           "classifier_id": "Machine_Contact_Enterprise_SET_778931065",
#           "name": "Machine_Contact_Enterprise_SETI_v1_"
#         }
#       ]
#     }
#   ],
#   "custom_classes": 4,
#   "images_processed": 1
# }

# %% [markdown]
# <br/>
# ## Run the Complete Test Set

# %%
#Create a dictionary object to store results from Watson

from collections import defaultdict

class_list = ['squiggle', 'noise', 'narrowband', 'narrowbanddrd']

results_group_by_class = {}
for classification in class_list:
    results_group_by_class[classification] = defaultdict(list)
    
failed_to_classify_uuid_list = []

print classifier_id

results_group_by_class
# Out:
# Machine_Contact_Enterprise_SET_778931065
# {'narrowband': defaultdict(list, {}),
#  'narrowbanddrd': defaultdict(list, {}),
#  'noise': defaultdict(list, {}),
#  'squiggle': defaultdict(list, {})}

# %%
# locate test archives that were produced in step 3 and add them to the test set
test_set = []
for classification in class_list:
    test_set = np.concatenate((test_set, sorted(glob.glob('{}/testset_*_{}.zip'.format(zipfilefolder, classification)))))

# %%
test_set
# Out:
# array([ '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_squiggle.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_11_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_12_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_13_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_14_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_noise.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_narrowband.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_narrowbanddrd.zip',
#        '/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_narrowbanddrd.zip'],
#       dtype='|S135')

# %%
for image_archive_name in test_set:
    image_count = 0
    # count number of images in <image_archive_name>
    with zipfile.ZipFile(image_archive_name,'r') as image_archive:
        images = image_archive.namelist()
        image_count = len(images)

    # bulk classify images in <image_archive_name>
    with open(image_archive_name, 'rb') as images_file:
        print 'Running test ({} images) for {}... this may take a while.'.format(image_count, image_archive_name)
        startTimer = timeit.default_timer()
        classify_results = vr.classify(images_file=images_file, classifier_ids=[classifier_id], threshold=0.0)
        # print(json.dumps(classify_results, indent=2))
        # identify class from ZIP file name, e.g. testset_10_squiggle.zip
        mo = re.match('^(.+)_(\d+)_(.+)\.zip$',image_archive_name.split('/')[-1])
        classification = mo.group(3)
        resdict = results_group_by_class[classification]
        passed = 0
            
        for classify_result in classify_results['images']:
            pngfilename = classify_result['image'].split('/')[-1]
            uuid = pngfilename.split('.')[0]
                
            maxscore = 0
            maxscoreclass = None

            if "error" in classify_result:
                # print error information
                print classify_result
                #add to failed list
                failed_to_classify_uuid_list.append(uuid)                  
            else:
                classifiers_arr = classify_result['classifiers']
                score_list = []
                for classifier_result in classifiers_arr:
                    for class_result in classifier_result['classes']:
                        score_list.append((class_result['class'],class_result['score']))
                        if class_result['score'] > maxscore:
                            maxscore = class_result['score']
                            maxscoreclass = class_result['class']
                            
                #sort alphabetically
                score_list.sort(key = lambda x: x[0])
                score_list = map(lambda x:x[1], score_list)
                        
                if maxscoreclass is None:
                    print 'Failed: {} - Actual: {}, No classification returned'.format(pngfilename, classification)
                    #print(json.dumps(classify_result, indent=2))
                elif maxscoreclass != classification:
                    print 'Failed: {} - Actual: {}, Watson Predicted: {} ({})'.format(pngfilename, classification, maxscoreclass, maxscore)
                else:
                    passed += 1
                    print 'Passed: {} - Actual: {}, Watson Predicted: {} ({})'.format(pngfilename, classification, maxscoreclass, maxscore)

                if maxscoreclass is not None:
                    resdict['signal_classification'].append(classification)
                    resdict['uuid'].append(uuid)
                    resdict['watson_class'].append(maxscoreclass)
                    resdict['watson_class_score'].append(maxscore)
                    resdict['scores'].append(score_list)
                else:
                    #add to failed list
                    failed_to_classify_uuid_list.append(uuid)                
           
        stopTimer = timeit.default_timer()
        
        print 'Test Score: {}% ({} of {} Passed)'.format(int((float(passed) / image_count) * 100), passed, image_count)
        print 'Tested {} images in {} minutes'.format(image_count, int(stopTimer - startTimer) / 60)
        
print "DONE."
# Out:
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_squiggle.zip... this may take a while.
# Passed: 68ee9508-d5bd-4411-a74e-9aa8e889b0a1.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.955406)
# Passed: bf4d4422-5ae6-45bd-8358-9b3317fd8526.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.93086)
# Failed: 9a5575f9-9f09-49ce-88c3-a6ea74b8a958.dat.png - Actual: squiggle, Watson Predicted: narrowbanddrd (0.467183)
# Passed: ed2b0804-4911-46e2-b6fc-4fe307e137ab.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.94508)
# Passed: 54fd0346-00f6-42c4-9097-aa78ee27500f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.935837)
# Passed: 641df498-db1a-4aa6-9c70-ba0314f225ef.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.729358)
# Passed: 9803a09b-0503-4bd3-9dbb-37f0f405ac88.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.943656)
# Passed: 611a7031-900a-41e6-a47d-c4a0764ec42f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953889)
# Passed: d81bcb04-c968-4a85-8968-7b57a137a697.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956807)
# Passed: 4ab7e5ff-c0ad-4bbc-b754-288a074c9b9b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.923908)
# Passed: 20594160-d72b-472d-95bc-3e6f695fbc40.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959373)
# Passed: 8c191145-71ba-4a60-9574-4b79e6422acc.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956928)
# Passed: 284d21fb-9e08-4e47-b057-2f1c5bed5dd7.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.951706)
# Passed: 573fd533-b9d7-438f-a743-7808345740b0.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.940817)
# Passed: 8470806f-9150-40ec-b80d-a4a1fa54e37f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.925455)
# Passed: 1ac1f4f0-bb3f-4d1d-a54c-46440a1d7141.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960237)
# Passed: 1e5339f8-8ed0-4b4b-8001-8d93a4e51949.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953984)
# Passed: 1c396696-baac-418b-9c14-bd798172ac61.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963391)
# Passed: e382aa1f-5d2d-492e-9a11-3f5cda4e7815.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.96031)
# Passed: ee3157b9-2d7f-45c5-9e5b-596921d6352d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.934293)
# Test Score: 95% (19 of 20 Passed)
# Tested 20 images in 0.133333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_squiggle.zip... this may take a while.
# Passed: 5532ed42-7770-4ae5-84f0-55c2cee8a667.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.965264)
# Passed: e3f4b053-9bd1-4629-83ca-695246927e39.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952116)
# Passed: fba02404-a065-4a19-9102-b91671ad2499.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958771)
# Passed: 96ddb6a4-eaf8-46c9-b679-025fc7f96a18.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961068)
# Passed: 7a3c3b2d-286c-41f7-9142-2f9520ca2caf.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952118)
# Passed: 21c412c0-6f85-4dfc-a332-aa2df8e41fd9.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.966203)
# Passed: d7ebc047-b90c-4489-bc78-b5db4b86a262.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.853211)
# Passed: 46069cb0-7300-4e90-b122-b3abe7c92227.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960671)
# Passed: 23ce752b-26c0-430e-96ed-3de671d1bda6.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.918558)
# Passed: cbe0d7d4-8b80-4c47-b4ce-99a3d6571d4e.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.876014)
# Passed: 77107e6c-65e0-492e-a994-02ede07f0d3b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.950843)
# Passed: 7dd694b7-0f4f-4510-adf7-cbec3b210bd9.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.762615)
# Passed: f0461f3f-269a-4453-aa54-f363d620ecdf.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964222)
# Passed: 874fec03-6134-459f-9bf8-efed9c0e8c07.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.949657)
# Passed: bf555318-3f3f-4503-89d2-54b899b41bf0.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.742981)
# Passed: 41b6d1f9-78b6-4dbe-872f-502bc867eb4c.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960811)
# Passed: 33e66bd3-0bde-4558-8a65-1a4184525d11.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.916369)
# Passed: 6c77e429-d0a4-4abf-8c2d-71f98ccb6c8b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.876459)
# Failed: 8dd7e1d3-d030-43b4-bc72-38764edcf8b1.dat.png - Actual: squiggle, Watson Predicted: noise (0.987748)
# Passed: 78bbf8d3-d4d9-42ca-ab26-e487e29e8a26.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.925682)
# Test Score: 95% (19 of 20 Passed)
# Tested 20 images in 0.15 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_squiggle.zip... this may take a while.
# Passed: 88b5b627-c508-4279-8729-a1853b57c7dc.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.87978)
# Passed: 26b7bc35-46e5-4c7a-8155-1212f65929eb.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.941283)
# Passed: a84999b6-8e0b-4f59-a05c-69981cd17bc1.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963845)
# Passed: 35a22155-cc90-4356-bfed-a165a67ff579.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.945496)
# Passed: f6ac9460-f31d-4c12-9883-de4615366a65.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958451)
# Passed: 76f3d2d8-588d-43eb-bca0-e1b6e9631d85.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.950861)
# Passed: 6bcb9648-b4da-443a-9e6a-eb26acdf082d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960606)
# Passed: 21e23aed-5376-4c08-b398-d17e7ace2fb8.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.894396)
# Passed: 4f263793-8d94-416a-94e8-701d88a8429b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.829549)
# Passed: a41e55a9-c018-4f04-adc9-95b7b4a26a2e.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961751)
# Passed: 13be283b-e718-41b3-9704-5312a112148b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961627)
# Passed: 534d63a8-2689-4807-803b-c4b17c43ab53.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.936945)
# Passed: c9e68f0e-8456-4db0-9266-a033038e6a0a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.940309)
# Passed: 174e0a2f-0504-4394-bdd7-c623a79f5ffd.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.954621)
# Passed: 7b31f440-b62f-4d83-94dd-e6c9890c46b5.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958276)
# Passed: e9074c19-aa06-4d89-bece-2a82e16b7509.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.903578)
# Passed: e08a1875-12b3-4c87-bc73-231d977f4966.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.965045)
# Passed: cf606038-88d1-44cc-9971-29d3d8da4446.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.947637)
# Passed: 25f3939c-9215-472e-a0c4-1b6e8766936b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.962334)
# Passed: dab31c51-cd94-47a5-bcf4-4479579b565b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.955418)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.116666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_squiggle.zip... this may take a while.
# Passed: 3baf84b0-c489-40c8-8203-b7c0e5ec9a21.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.943206)
# Passed: 72710c56-cec7-4cc9-b3a9-369044012356.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963092)
# Passed: 5e799670-cde4-4d65-8a08-54f53396cb02.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956649)
# Passed: e38d6c70-6c6a-43da-82a8-10f5e1647624.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956302)
# Passed: 6d1b0036-5658-4cf3-861a-687983472804.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.903673)
# Passed: 4958c0a2-fad8-4904-8d5a-8e75ee4013b4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.943954)
# Passed: cd90e133-4bbd-49d1-837d-0906507e4129.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.893656)
# Passed: ad0aed19-e17e-4288-a2ba-acd666d69465.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963363)
# Passed: 600a5176-94ba-4b5f-bb2f-847086bc7fb9.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952693)
# Passed: ec953af4-5a56-48e1-a881-870a626bf4c4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.94476)
# Passed: 1b8ba1c7-c778-4e61-b3a5-1403d803b5dd.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.861747)
# Passed: 6f2dbd4e-27b2-4fbe-b090-57e16cdebdbb.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952391)
# Passed: 0ef517da-e401-48bb-9bb2-2aac702cd07d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.955826)
# Passed: d4454b36-ef9c-4788-9890-1ac4843b1354.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.95181)
# Passed: 883bb00d-6b6d-45fa-bb8b-ae589e7ac251.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.905143)
# Passed: 1b4556b7-4dd0-4c0d-88b8-1559be939f7d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.95215)
# Passed: 7299ab41-68fe-4a08-8f0c-0d2fb7cdb4aa.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953402)
# Passed: 417e00d7-4df6-4165-b07c-dd5f36f0ba63.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.924447)
# Passed: a54d1a61-0111-475f-8ba9-d8d479e90b98.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960481)
# Passed: 423faebb-5fc2-4a07-b47d-b6cef3bd8255.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963166)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.116666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_squiggle.zip... this may take a while.
# Failed: fa37e3d6-0ffc-4d0b-9691-0f161c3d5990.dat.png - Actual: squiggle, Watson Predicted: noise (0.890473)
# Passed: d2de3445-d4f5-4477-a79e-7b0d4d0bc6ad.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959787)
# Passed: aa154372-161a-4d3d-a539-cf9d8f8d22af.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956826)
# Passed: 8fcfe7d3-f4ba-4bbb-972c-1ac94b916163.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956153)
# Passed: 9f569985-bbd7-4195-bdde-0c5730594828.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960475)
# Failed: 8a18698a-da18-4e51-98c7-0b44350d36cf.dat.png - Actual: squiggle, Watson Predicted: narrowbanddrd (0.818593)
# Passed: 93b2c443-f223-4fb6-9648-a6bc576fb24a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956856)
# Passed: c5ed02e0-92c2-45b1-9dd5-a88c697a5466.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.957561)
# Passed: e5ec6910-fe38-4994-af28-68e19d5a5025.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963217)
# Passed: eb36435f-565d-4c4a-a99b-2523933a2dec.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.957573)
# Passed: 62a02d40-282f-4fb0-b118-7628591f9d78.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.962028)
# Passed: ab71f60e-2aa3-475b-ab6f-6efdad252a88.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960388)
# Passed: f4bc26e1-ac4d-4293-a8b8-c3c9a57e2006.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.908672)
# Passed: 509fe981-b6b6-4986-a917-685b3a4d8e4e.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.951505)
# Passed: 0263d3d5-531a-412b-8c44-bded066adb14.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.96139)
# Passed: fdb0e9c1-0bef-49a1-a767-07eba79470fb.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.965139)
# Passed: d0b6ea0e-1b07-4b30-887e-dbe06841346d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959558)
# Passed: 0ee5a1fb-b5a5-464c-953f-5ab8faefc552.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964189)
# Passed: b47ec6a4-a4a9-4d38-aac6-33416df9d1b1.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.915143)
# Passed: ed3a1f25-d33a-4fb0-81c3-2fe7ba55dafc.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.947073)
# Test Score: 90% (18 of 20 Passed)
# Tested 20 images in 0.116666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_squiggle.zip... this may take a while.
# Passed: 4e020e83-5c2e-464a-a9d0-915c8f5db8d4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.956612)
# Passed: 7197c169-413f-4e48-b3e9-e4f289c9ea36.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.96562)
# Passed: 62972e7e-86e1-4282-af2f-329a78a6e7c7.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.962463)
# Passed: 050e3a4c-0a35-4171-8a1e-27315fba3e0d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.927339)
# Passed: bcf7c231-c6e6-494e-a979-14a887c9aa17.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.881126)
# Passed: 77620c45-479f-4688-a331-37a285b8bba1.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.946991)
# Passed: 874964b3-4ce5-4a91-b89f-c9af4dca1016.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.906337)
# Passed: f54837ab-d2f6-4c28-a816-ca760d1acab1.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.935092)
# Passed: c264521f-2265-4102-bc6c-1b10840f3aee.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.913364)
# Passed: 5fe231f4-427c-439c-81fd-666a729f5f48.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959939)
# Passed: 7f4ae9a7-e7c4-4335-8c15-884f6bc3b694.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.94903)
# Passed: 655915d6-8576-4ee5-9d93-c919302a0ff2.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.951669)
# Passed: e16b3d30-e515-47ff-a27a-c798354fa63a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.936669)
# Passed: cbfb0826-e6a9-49f2-8f1b-9e94c15e52fc.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.947273)
# Passed: 303c7aa5-4661-411a-bd21-61f423657776.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.914468)
# Passed: 27e38771-433f-4e33-bf11-4b32873ea349.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.96254)
# Passed: 0a6861e1-4ff6-45b1-b5a8-c02a533ea2ee.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959324)
# Passed: 24cc63f6-cea3-4954-a1e7-2e39fffbcc31.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.933844)
# Passed: b11a9e2d-48d5-4f8a-b2e9-42a76c6ac7f7.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963318)
# Passed: 931a3aa6-f323-4178-bba1-cad7040a6d76.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.96241)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.216666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_squiggle.zip... this may take a while.
# Passed: bf9c77e7-40d4-4fd2-a69a-75edc3d930bb.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.844664)
# Passed: b48da995-8015-4e65-a935-8e44f40c3745.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.955942)
# Passed: 9846d4c1-0836-4d87-99c3-0af87dd6c3e3.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.930898)
# Passed: a3782996-963b-402f-b920-052f4cf741af.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.965014)
# Passed: 98faebf6-8cf9-4f3d-afaa-001b724059ca.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964516)
# Passed: 70aec524-28cb-406e-a5e9-ce20de92e41b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.932164)
# Passed: f6fd7a0b-c6dd-4f04-ac5e-3315426e7db8.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.930711)
# Passed: 609d78f4-5b3d-428d-9427-1fcab9b33604.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.942241)
# Passed: 22a3b532-f01e-44a5-8960-27dd0ba47b84.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961663)
# Passed: 84cf2032-1527-4cf0-8498-125f5baa1c5e.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.949526)
# Passed: 5343c2d2-bc58-4bf8-8e0a-5bd3bf203ded.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.910153)
# Passed: f9018f49-5e93-4ba4-8de7-de9d53136cfc.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953759)
# Passed: 4598a286-34c0-4f13-9ee0-87bdf2b361fe.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963696)
# Passed: 787c39fc-d65a-4dff-a59a-48f73976402f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.792022)
# Passed: f3a14e5c-73f1-4ab8-8cb3-561339d035de.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961708)
# Passed: a98d43c4-0362-4a88-b234-6b9c9f160905.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.900234)
# Passed: 3f35b6b4-f963-4f83-84e1-ac221f4998c9.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.639153)
# Passed: 7b7a162d-9562-41d8-9dce-3d81a624b4b4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963514)
# Passed: 20f7760f-b699-4a86-930f-389c2aa0f154.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.930796)
# Passed: 976a80d2-2966-4232-acff-1ae1b7209578.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952793)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.166666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_squiggle.zip... this may take a while.
# Passed: eb1eedd5-1021-4905-87b7-c4d363275458.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964198)
# Passed: e3cf0373-a336-4c1b-a20d-6aaf75758b69.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.946406)
# Passed: 4ab2bc49-5b8c-4535-a52e-ac82ef63b732.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.957806)
# Passed: b7c1dc56-0f50-4779-b65e-2068d66c38a8.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964551)
# Passed: c937fac5-e2f0-4efa-8589-2adeacce3c5c.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959092)
# Passed: 8bb5fa05-6e19-4bb6-93d5-508d43452eaf.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.965125)
# Passed: 3c810e54-2c10-4a02-9251-b961c599c7df.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953536)
# Passed: 02dc90d2-ffea-4b54-b0f5-bca10844f757.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.948987)
# Passed: 3432abfe-f899-410b-86ab-11613456e0ad.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958985)
# Passed: dd12a6ee-99f2-490b-942f-eac012e572f6.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.910241)
# Passed: 44099811-9832-4c48-b902-9995ef99b38c.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.947429)
# Passed: b2db9fad-6149-48e5-bd64-01fcf02ca6f4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960518)
# Passed: f0f79111-5dbb-4ff2-8b86-d90e472073d0.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.94954)
# Passed: 0fb1b345-e771-474e-809f-a849b41548b4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.902951)
# Passed: 2c9cbf5a-95f8-4ad8-bb63-6840fe7e6d2f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964417)
# Passed: b66f57f2-aaaf-4608-9ced-cdcfe5483364.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958703)
# Passed: 8fa516f4-73dd-4a36-8457-394dbcac8e33.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952414)
# Passed: d018a62b-a4ad-4fc2-9a27-6e0a42d1e2d3.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.944486)
# Passed: 5808065e-06e4-4493-8c83-3092760fc159.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959906)
# Passed: c5c37845-68be-43e2-863c-2d65053b4d2d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964358)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.15 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_squiggle.zip... this may take a while.
# Passed: 794734ba-2d1e-496b-9343-b01b67c40ba4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.954769)
# Passed: 3297b81a-4513-4c10-b0ba-dfa14a242be7.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.896884)
# Passed: 57ccd8c8-bc5a-43bf-856d-58399d243101.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961159)
# Passed: ee4bde2e-3ed0-41b0-ab96-7e9f6d07ca7c.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.95228)
# Passed: 04dc75c3-0bef-4456-8d58-43e22a85eb64.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.966239)
# Passed: fb620240-fa4c-405c-9ff9-d15c1237caf3.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.964368)
# Passed: c43af4da-65d6-488d-bae6-c623867d4d14.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.954807)
# Passed: e3449cb7-dd79-4b5b-96aa-7685d1e4183a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.960806)
# Failed: d679ceaf-c7bc-4d2d-920e-c2e09851e838.dat.png - Actual: squiggle, Watson Predicted: narrowbanddrd (0.888257)
# Passed: d72a2868-f795-48d5-9c8e-1408df5e287b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963769)
# Passed: c76944be-7fbc-4d3b-99f0-6413e58daf2d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.95296)
# Passed: 0ac854ea-bf34-4c13-9094-62ec07458034.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952435)
# Passed: 2cc9a3cf-4b62-42ab-9fc6-d1ce1d7a1e77.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.90137)
# Passed: dca48f58-70e6-4673-b121-acf0b4011720.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.929207)
# Passed: 8d9adc5e-e8e5-4e36-97d1-18ad52845bea.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.948032)
# Passed: 97a69313-71ea-4e39-a18a-6bda7ca5fe89.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.951715)
# Passed: 05f512a2-147e-4013-9ef0-318d184f87a2.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.966264)
# Passed: a99cf37c-82b8-46d0-853b-9ce60c8e33c6.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.941139)
# Passed: e8054648-b18d-48f3-84df-6aa91b3ec331.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.959821)
# Passed: d387c7ca-0639-4b35-a248-515095753059.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.955685)
# Test Score: 95% (19 of 20 Passed)
# Tested 20 images in 0.133333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_squiggle.zip... this may take a while.
# Passed: e0cb0212-d7d7-43b1-a0af-821fee1cae9b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.939891)
# Passed: 3e5e68a1-49bc-4c00-99cb-b5ba7fe0f9f5.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.953365)
# Passed: a8d64f69-ecfc-4718-8bfd-abd27f0eef08.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.945894)
# Passed: 994d2547-88d4-48e6-8551-e74eaaadb33a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.949565)
# Passed: d0d9ee29-020a-4417-ab8a-99db2f68e3e3.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.9544)
# Passed: 7583509f-5507-4115-8fa0-07675683321a.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.869594)
# Passed: afc734e1-4f20-4e8b-b5f7-60472ec93c31.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.933831)
# Passed: e441775b-70ff-42ee-bc6f-c26cf5a9d548.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.951882)
# Passed: f03683cb-a12b-46e5-9ff2-67af124e70e9.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.933782)
# Passed: 417fb305-7ba9-43e8-acdd-b1462919e2ec.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.941099)
# Passed: e0cff2bf-7b19-41b9-a59a-d66829b475be.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.948498)
# Passed: 7ff887e5-a172-4bcb-8921-0a1b3921033d.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.89299)
# Passed: d4dd3469-2070-4dac-9a72-e8f1b08a3b63.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.954405)
# Passed: b1a0e208-9366-4964-b91a-85bba4cb563f.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.952595)
# Passed: 91bb27c2-448e-42e7-9709-a7396a70981b.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.939636)
# Passed: 6be5b161-2baf-458e-84a1-0c2ac07d1047.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.963665)
# Passed: 50347ad9-1e08-4e81-af6b-9ff200f6ef3c.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.94859)
# Passed: 81215657-a08e-4df6-90b2-4531e7d70520.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.958923)
# Passed: f9fc0623-5506-4e8c-aa4f-6becae520de4.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.961067)
# Passed: 53a3cbd7-d9c8-4197-a1dc-530101efa6ea.dat.png - Actual: squiggle, Watson Predicted: squiggle (0.962425)
# Test Score: 100% (20 of 20 Passed)
# Tested 20 images in 0.15 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_10_noise.zip... this may take a while.
# Passed: f9e62f52-2c02-4f27-8cda-ee4156e31468.dat.png - Actual: noise, Watson Predicted: noise (0.992893)
# Passed: b538a5a6-757a-4053-ac3a-2e20f09ed2ef.dat.png - Actual: noise, Watson Predicted: noise (0.992803)
# Passed: 41176b3b-9c62-4ddc-8045-4bf27a25d57d.dat.png - Actual: noise, Watson Predicted: noise (0.992815)
# Passed: a62abf54-c4c4-44e7-b37b-4d2c7192a635.dat.png - Actual: noise, Watson Predicted: noise (0.99295)
# Passed: 73066802-31ea-4e70-acc5-e3ddbf2e9565.dat.png - Actual: noise, Watson Predicted: noise (0.992674)
# Passed: 54401fc5-44b9-4e6e-8861-91a3a03d3ea3.dat.png - Actual: noise, Watson Predicted: noise (0.99219)
# Passed: 77fe543c-4af9-4660-8a85-bfe1c5420af8.dat.png - Actual: noise, Watson Predicted: noise (0.992702)
# Passed: 12f8352f-bee8-4a7f-bfcf-32db78532f35.dat.png - Actual: noise, Watson Predicted: noise (0.992877)
# Passed: ee729c61-bbc3-433f-a6f3-e5cf856b3ea4.dat.png - Actual: noise, Watson Predicted: noise (0.992797)
# Passed: f10963d4-eeb2-4905-96cb-70599631ab06.dat.png - Actual: noise, Watson Predicted: noise (0.992912)
# Passed: 43219f67-79ad-48b3-b6ea-f7f1371b4738.dat.png - Actual: noise, Watson Predicted: noise (0.992818)
# Passed: 533548c4-3414-4d1a-a27e-4d839c73d818.dat.png - Actual: noise, Watson Predicted: noise (0.992554)
# Passed: cc793790-073b-41bf-9419-62fbbd8a7f8f.dat.png - Actual: noise, Watson Predicted: noise (0.9919)
# Passed: a8337a1a-ccc8-42d2-b77b-192129081877.dat.png - Actual: noise, Watson Predicted: noise (0.992723)
# Passed: 46467a3b-f11c-4805-b449-582d54c915da.dat.png - Actual: noise, Watson Predicted: noise (0.992622)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_11_noise.zip... this may take a while.
# {u'image': u'/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_11_noise.zip/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/cleanPngs2/8ad7b163-0dbd-4b73-9243-cffcb19606be.dat.png', u'error': {u'error_id': u'server_error', u'description': u'An undefined server error occurred.'}}
# Passed: 43748ad2-f165-4f09-b567-bdad8dfc201f.dat.png - Actual: noise, Watson Predicted: noise (0.992876)
# {u'image': u'/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_11_noise.zip/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/cleanPngs2/c8697ec0-924d-4e00-a351-9ea2496f0ccd.dat.png', u'error': {u'error_id': u'server_error', u'description': u'An undefined server error occurred.'}}
# Passed: 042ef3b3-bcbf-456d-92f0-bd2a66b4f158.dat.png - Actual: noise, Watson Predicted: noise (0.992852)
# Passed: 82e8e181-a13b-4608-9efc-4fff1b4b10d4.dat.png - Actual: noise, Watson Predicted: noise (0.99264)
# Passed: d5d83d4d-7ca8-4fa6-9dcd-c28cbc394230.dat.png - Actual: noise, Watson Predicted: noise (0.99177)
# Passed: 6dcf5a61-db24-4c8e-9b91-63d3f9989391.dat.png - Actual: noise, Watson Predicted: noise (0.992055)
# Passed: 0a88d056-91d7-4165-b3dd-18dfffb85e01.dat.png - Actual: noise, Watson Predicted: noise (0.993019)
# Passed: 0c8a833c-240c-47b7-aaac-064a2e6572a7.dat.png - Actual: noise, Watson Predicted: noise (0.99278)
# {u'image': u'/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_11_noise.zip/gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/cleanPngs2/7950e591-3602-4835-8bb8-564ecac40302.dat.png', u'error': {u'error_id': u'server_error', u'description': u'An undefined server error occurred.'}}
# Passed: 0b22b5fe-4a93-4130-8e92-3251562358b1.dat.png - Actual: noise, Watson Predicted: noise (0.992442)
# Passed: 9125e448-4e28-4b52-ba96-fad5c5664408.dat.png - Actual: noise, Watson Predicted: noise (0.992346)
# Passed: 0ece65a9-11a5-4237-a5a6-ee8a92d426eb.dat.png - Actual: noise, Watson Predicted: noise (0.99246)
# Passed: 8a5aef5f-0d00-4eec-9b27-76f797f242ae.dat.png - Actual: noise, Watson Predicted: noise (0.992792)
# Passed: bb18238e-57b9-4c26-b2f9-7888831ceb96.dat.png - Actual: noise, Watson Predicted: noise (0.992807)
# Test Score: 80% (12 of 15 Passed)
# Tested 15 images in 0.116666666667 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_12_noise.zip... this may take a while.
# Passed: 2737ef7e-2c02-4e5d-9488-6c07063466c6.dat.png - Actual: noise, Watson Predicted: noise (0.992775)
# Passed: 611c5b35-1ab1-436e-9e2f-300ce7421dae.dat.png - Actual: noise, Watson Predicted: noise (0.992179)
# Passed: 0f14d2a5-cf6b-429b-a8f6-8cd158df7692.dat.png - Actual: noise, Watson Predicted: noise (0.992511)
# Passed: c12e6118-7c5a-4787-a31c-438b2277f94d.dat.png - Actual: noise, Watson Predicted: noise (0.99168)
# Passed: 40be4e25-2c14-4e12-a56f-85b803159cf4.dat.png - Actual: noise, Watson Predicted: noise (0.992913)
# Passed: eceb6026-f477-41ea-b12f-4828630d11c8.dat.png - Actual: noise, Watson Predicted: noise (0.992693)
# Passed: 2a9598de-b34b-495b-8054-d4664f802961.dat.png - Actual: noise, Watson Predicted: noise (0.99259)
# Passed: 6dc29933-16fb-4572-a883-112890a8c771.dat.png - Actual: noise, Watson Predicted: noise (0.992751)
# Passed: b22a633b-91da-4e6c-9119-128cc210c202.dat.png - Actual: noise, Watson Predicted: noise (0.992896)
# Passed: ad40809b-9f87-4eef-80d1-556022698032.dat.png - Actual: noise, Watson Predicted: noise (0.992451)
# Passed: 7fe67a01-1259-4f6a-a4bd-b4715a0d390a.dat.png - Actual: noise, Watson Predicted: noise (0.992884)
# Passed: db9a326b-a4d3-4019-9507-5b33ad0ab919.dat.png - Actual: noise, Watson Predicted: noise (0.99271)
# Passed: 5c29cb85-e059-42a6-8f69-be1aba024e5c.dat.png - Actual: noise, Watson Predicted: noise (0.99296)
# Passed: 0325f6ad-c09b-497d-8c81-99a89e0df414.dat.png - Actual: noise, Watson Predicted: noise (0.992485)
# Passed: 3effca5a-e00a-4d08-9a41-ddbf3a6481c2.dat.png - Actual: noise, Watson Predicted: noise (0.992927)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_13_noise.zip... this may take a while.
# Passed: f5d06f6e-90cd-4171-8859-e5ccd859bde7.dat.png - Actual: noise, Watson Predicted: noise (0.992482)
# Passed: 3b617973-3f70-4480-af9e-ea2aaaa9fe34.dat.png - Actual: noise, Watson Predicted: noise (0.992242)
# Passed: 7e8aa203-0249-45b7-9fd6-6198824c6c3a.dat.png - Actual: noise, Watson Predicted: noise (0.992342)
# Passed: 6ebd9b76-eb5f-4672-95cf-e6549dacb441.dat.png - Actual: noise, Watson Predicted: noise (0.992512)
# Passed: 2538b111-22ec-4e9f-a94a-3386e902353e.dat.png - Actual: noise, Watson Predicted: noise (0.992538)
# Passed: 6e1b0232-4c3d-45b4-97d4-7a77a0bce881.dat.png - Actual: noise, Watson Predicted: noise (0.992784)
# Passed: 8fc2def3-01ad-4089-aa41-2746077e93b1.dat.png - Actual: noise, Watson Predicted: noise (0.992151)
# Passed: 3010d8a5-a0a9-4063-aac9-1f231b0f3407.dat.png - Actual: noise, Watson Predicted: noise (0.992934)
# Passed: a1ba4bca-0fb0-4227-ab35-3f2556ace744.dat.png - Actual: noise, Watson Predicted: noise (0.992861)
# Passed: 33d4c5ec-4dd1-47a0-a5aa-cfe715f7bfb9.dat.png - Actual: noise, Watson Predicted: noise (0.992364)
# Passed: 82957099-40e8-4cc1-834b-618d0d4bcaac.dat.png - Actual: noise, Watson Predicted: noise (0.992464)
# Passed: d290d06c-1265-4010-9b8f-30ef8fc4d6a8.dat.png - Actual: noise, Watson Predicted: noise (0.992904)
# Passed: 23d79afd-4cf2-4295-ba8c-34c9645a4166.dat.png - Actual: noise, Watson Predicted: noise (0.992559)
# Passed: 37064eee-fd25-4135-add5-9e5e12ed45ac.dat.png - Actual: noise, Watson Predicted: noise (0.992883)
# Passed: 1e83f192-0fb3-4605-9e58-60a8c2a29df4.dat.png - Actual: noise, Watson Predicted: noise (0.992668)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.15 minutes
# Running test (5 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_14_noise.zip... this may take a while.
# Passed: ceac976c-3040-4e0d-b9df-236d17e7b1fb.dat.png - Actual: noise, Watson Predicted: noise (0.992561)
# Passed: a0e51cf7-89f2-4a54-bc20-756b2832db2d.dat.png - Actual: noise, Watson Predicted: noise (0.992732)
# Passed: f536a727-112e-4fc6-becd-52d8eea649bd.dat.png - Actual: noise, Watson Predicted: noise (0.992753)
# Passed: 6ac5babd-9672-444e-8d1d-1eb2ecbb7d92.dat.png - Actual: noise, Watson Predicted: noise (0.992645)
# Passed: fe584a74-09ed-4e6a-be62-279c75e8a888.dat.png - Actual: noise, Watson Predicted: noise (0.992554)
# Test Score: 100% (5 of 5 Passed)
# Tested 5 images in 0.0666666666667 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_1_noise.zip... this may take a while.
# Passed: 95f3cf7a-d261-4e0b-8b82-0114c18b3e6f.dat.png - Actual: noise, Watson Predicted: noise (0.992602)
# Passed: a4928418-3ae7-42a5-bc66-c3e53f2f38b7.dat.png - Actual: noise, Watson Predicted: noise (0.992195)
# Passed: 8a8632de-68d7-4140-ab0e-578ae1fb9da9.dat.png - Actual: noise, Watson Predicted: noise (0.992425)
# Passed: 68c37aeb-70ed-46b4-b94b-daa352ed7b9c.dat.png - Actual: noise, Watson Predicted: noise (0.992995)
# Passed: e697a630-e150-4ad8-a4c3-d1d882c66a31.dat.png - Actual: noise, Watson Predicted: noise (0.992507)
# Passed: 03199113-5b06-4675-8549-e40689ac8d10.dat.png - Actual: noise, Watson Predicted: noise (0.992714)
# Passed: 315aee09-85cb-4754-846c-92395d6a6b9f.dat.png - Actual: noise, Watson Predicted: noise (0.99287)
# Passed: 56468755-1967-461a-b2d5-4c90fb9cc915.dat.png - Actual: noise, Watson Predicted: noise (0.992846)
# Passed: 155cfa41-8a11-4f07-b1d7-9ddb61d653c5.dat.png - Actual: noise, Watson Predicted: noise (0.99243)
# Passed: 3819dc67-f10a-4874-a979-9aa89192d7ba.dat.png - Actual: noise, Watson Predicted: noise (0.992764)
# Passed: f9e0bc9a-51e7-431c-8af2-51c646257b06.dat.png - Actual: noise, Watson Predicted: noise (0.992537)
# Passed: e86b0bc3-e7f7-4af9-99bb-20bdc9e175da.dat.png - Actual: noise, Watson Predicted: noise (0.992371)
# Passed: dba4daa7-fea0-4c52-9577-7bf2d6508c35.dat.png - Actual: noise, Watson Predicted: noise (0.992624)
# Passed: 2cc2e990-470e-4f27-bb12-8fc1b02771bc.dat.png - Actual: noise, Watson Predicted: noise (0.99273)
# Passed: f173054b-b604-478d-8a02-a02e048c2b59.dat.png - Actual: noise, Watson Predicted: noise (0.9926)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_2_noise.zip... this may take a while.
# Passed: 2c5027c0-5353-40ee-90d4-8510a8b33ce9.dat.png - Actual: noise, Watson Predicted: noise (0.991872)
# Passed: df787b8c-587f-4489-9fe6-2054a5542720.dat.png - Actual: noise, Watson Predicted: noise (0.992709)
# Passed: 2750d442-3e13-40fe-af0e-46a6a71c4b63.dat.png - Actual: noise, Watson Predicted: noise (0.993092)
# Passed: 3856020b-0a41-4df1-8a24-a21af3124a8a.dat.png - Actual: noise, Watson Predicted: noise (0.992684)
# Passed: 31f7abbb-8fa9-4a01-bd55-4037565bf722.dat.png - Actual: noise, Watson Predicted: noise (0.992615)
# Passed: 3365ce86-27a1-46f6-9e29-067cf3012dfb.dat.png - Actual: noise, Watson Predicted: noise (0.992451)
# Passed: dc71111f-f45a-4755-a523-5c58497f474a.dat.png - Actual: noise, Watson Predicted: noise (0.992671)
# Passed: ad8f8799-9025-46ff-85b3-9cccc905a540.dat.png - Actual: noise, Watson Predicted: noise (0.992704)
# Passed: a4b4dea7-b6ba-4104-b837-079289aac12a.dat.png - Actual: noise, Watson Predicted: noise (0.992243)
# Passed: c26770f4-19b9-4587-abb4-dde30d2e7cce.dat.png - Actual: noise, Watson Predicted: noise (0.992969)
# Passed: 4e5a75c8-d8d1-47bb-8e16-fe18070121b1.dat.png - Actual: noise, Watson Predicted: noise (0.99258)
# Passed: c696d601-594c-49fc-ae54-cd30cc9efd0c.dat.png - Actual: noise, Watson Predicted: noise (0.992415)
# Passed: 83c15d26-13a2-4b17-bae5-2a89354220c3.dat.png - Actual: noise, Watson Predicted: noise (0.992627)
# Passed: 9f631655-866c-4758-a655-559a434a0fff.dat.png - Actual: noise, Watson Predicted: noise (0.992175)
# Passed: 7bdaabbe-b4e4-45bb-83fd-ddf5704ca9aa.dat.png - Actual: noise, Watson Predicted: noise (0.992924)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_3_noise.zip... this may take a while.
# Passed: d0668e33-8b94-4dff-9779-d2e54414b6a9.dat.png - Actual: noise, Watson Predicted: noise (0.992447)
# Passed: a5e7d55c-3d31-45f3-a79d-339709d066fa.dat.png - Actual: noise, Watson Predicted: noise (0.992895)
# Passed: c1bf18dc-12b3-4477-953a-82541784234e.dat.png - Actual: noise, Watson Predicted: noise (0.992789)
# Passed: ca90a9ff-c6dc-4bee-b8f9-5c3ce222f177.dat.png - Actual: noise, Watson Predicted: noise (0.992627)
# Passed: b0496195-4ca0-4837-9b76-607a4601ce07.dat.png - Actual: noise, Watson Predicted: noise (0.991897)
# Passed: d0aa7a4d-ec85-4ec8-b02c-055ea4f75cea.dat.png - Actual: noise, Watson Predicted: noise (0.992905)
# Passed: ea0d3003-4848-4a76-8041-8a1dfa8e1177.dat.png - Actual: noise, Watson Predicted: noise (0.992824)
# Passed: 443a8f18-4401-4771-81a7-0773d9b10e17.dat.png - Actual: noise, Watson Predicted: noise (0.992965)
# Passed: 3adc4a57-cc63-44ed-9917-fd1c51c79f81.dat.png - Actual: noise, Watson Predicted: noise (0.991509)
# Passed: 11753e8e-4cba-4879-b02c-ce9198de171d.dat.png - Actual: noise, Watson Predicted: noise (0.992844)
# Passed: 0b883dcd-1cd3-4bd7-b831-f667279f9072.dat.png - Actual: noise, Watson Predicted: noise (0.992662)
# Passed: e92e322d-96af-428c-b6c6-8b579ca0e95b.dat.png - Actual: noise, Watson Predicted: noise (0.992754)
# Passed: a0e659fe-d0a9-43c6-9560-7532325920e1.dat.png - Actual: noise, Watson Predicted: noise (0.992874)
# Passed: aa94c86e-2e1b-4d23-b5f1-8b69fc40044d.dat.png - Actual: noise, Watson Predicted: noise (0.992517)
# Passed: 50cdc5c9-2d3f-4f38-a018-1cf7b87e9f59.dat.png - Actual: noise, Watson Predicted: noise (0.992646)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.166666666667 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_noise.zip... this may take a while.
# Passed: 462d549f-8c41-4b63-9c9f-1355412b78d5.dat.png - Actual: noise, Watson Predicted: noise (0.992086)
# Passed: cfc6d87b-ebd0-4cd5-a18a-1e5aec13346b.dat.png - Actual: noise, Watson Predicted: noise (0.991988)
# Passed: 5634e09e-da8f-4e0b-881b-998bf916ec94.dat.png - Actual: noise, Watson Predicted: noise (0.992629)
# Passed: 851c24cc-2a33-4b67-9413-eff35ff1cac6.dat.png - Actual: noise, Watson Predicted: noise (0.992914)
# Passed: c96a242e-aaac-4407-9bf0-58ce6a5529b7.dat.png - Actual: noise, Watson Predicted: noise (0.992148)
# Passed: 815cd9a7-9a44-419a-9c0a-5764665cd7cf.dat.png - Actual: noise, Watson Predicted: noise (0.992097)
# Passed: f6050435-3cca-4218-8a65-5ed1d35a638f.dat.png - Actual: noise, Watson Predicted: noise (0.9928)
# Passed: d39a5219-2ccd-48ae-ab5b-0175773f73ca.dat.png - Actual: noise, Watson Predicted: noise (0.992837)
# Passed: b30fc6d2-96f1-4c71-9a7c-471e56dc2ed9.dat.png - Actual: noise, Watson Predicted: noise (0.992776)
# Passed: 613189fe-ac6b-40a9-95a1-6dd1112726c6.dat.png - Actual: noise, Watson Predicted: noise (0.992739)
# Passed: 23415db2-303b-4933-ab77-5a5bb1417a47.dat.png - Actual: noise, Watson Predicted: noise (0.992089)
# Passed: 01718726-869d-4393-b516-1f3ef42cf522.dat.png - Actual: noise, Watson Predicted: noise (0.992357)
# Passed: b2bdc803-68f4-46be-9eb5-2d7a25c5185a.dat.png - Actual: noise, Watson Predicted: noise (0.992662)
# Passed: b25be080-c5cf-496e-8020-abb4c0527ab0.dat.png - Actual: noise, Watson Predicted: noise (0.992712)
# Passed: 8820d122-3246-4d09-804d-c68768db8450.dat.png - Actual: noise, Watson Predicted: noise (0.992694)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.15 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_noise.zip... this may take a while.
# Passed: 675b826f-b2fe-4a84-a9e4-2ea62bd596d8.dat.png - Actual: noise, Watson Predicted: noise (0.991991)
# Passed: 742292c6-8e46-4c86-97af-0f2a2671e33d.dat.png - Actual: noise, Watson Predicted: noise (0.992898)
# Passed: 1d937da9-c0fd-4bc7-9d32-a45beced17df.dat.png - Actual: noise, Watson Predicted: noise (0.992687)
# Passed: 739d1568-1cb2-4496-a922-13ac9e43a175.dat.png - Actual: noise, Watson Predicted: noise (0.992438)
# Passed: 9b6a4b25-f662-470f-a229-b9f3770c31b9.dat.png - Actual: noise, Watson Predicted: noise (0.99304)
# Passed: c5a4e35b-aaba-4192-9d3e-ee3ce7e3831f.dat.png - Actual: noise, Watson Predicted: noise (0.992892)
# Passed: 4f8f1c0b-39b7-427e-a8a0-e0b150ab357c.dat.png - Actual: noise, Watson Predicted: noise (0.992471)
# Passed: f352303f-533b-43f9-865f-fe1e6867ee8f.dat.png - Actual: noise, Watson Predicted: noise (0.992448)
# Passed: f50b0db8-d31a-4c26-a2a4-fba258423fd8.dat.png - Actual: noise, Watson Predicted: noise (0.992761)
# Passed: ed71baa3-3e87-4a79-a027-e69e7ce620c4.dat.png - Actual: noise, Watson Predicted: noise (0.992236)
# Passed: 9e456a96-d214-427f-b95a-f85e0c59acfd.dat.png - Actual: noise, Watson Predicted: noise (0.992807)
# Passed: b0927b12-53df-4075-ba64-2af9e1c6eb70.dat.png - Actual: noise, Watson Predicted: noise (0.992712)
# Passed: 1a807a96-0eef-4375-8e67-eea7a1b7fe7c.dat.png - Actual: noise, Watson Predicted: noise (0.992776)
# Passed: c9c841c5-9208-4189-8920-8de27ba58220.dat.png - Actual: noise, Watson Predicted: noise (0.993022)
# Passed: 5858214e-c9c5-4ec5-baa3-c17e0eeb5940.dat.png - Actual: noise, Watson Predicted: noise (0.992562)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.166666666667 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_noise.zip... this may take a while.
# Passed: 66849617-2313-4f14-b3e7-63889cd92470.dat.png - Actual: noise, Watson Predicted: noise (0.992397)
# Passed: 70551f04-9aa9-453f-ae8a-8bd06d49d75d.dat.png - Actual: noise, Watson Predicted: noise (0.992296)
# Passed: 413764e5-2345-45e2-9583-b59c10f719f1.dat.png - Actual: noise, Watson Predicted: noise (0.992794)
# Passed: 3373d7d8-6e09-490b-810e-7c5a91ced552.dat.png - Actual: noise, Watson Predicted: noise (0.992878)
# Passed: f00f2de2-1dad-4082-b004-f3465d5439ca.dat.png - Actual: noise, Watson Predicted: noise (0.99254)
# Passed: 65a94fdd-7996-4f4c-adc6-df2d40279565.dat.png - Actual: noise, Watson Predicted: noise (0.992945)
# Passed: a6238f41-2772-461e-aeee-5a1ea00f4788.dat.png - Actual: noise, Watson Predicted: noise (0.992442)
# Passed: 5393f9c0-d85b-4ac9-be29-7a9cd8d7bea6.dat.png - Actual: noise, Watson Predicted: noise (0.992742)
# Passed: 833a0b1a-21ef-4a01-b039-75454c6a726e.dat.png - Actual: noise, Watson Predicted: noise (0.992913)
# Passed: 456a2590-adbe-4083-b502-33da358f02b9.dat.png - Actual: noise, Watson Predicted: noise (0.992914)
# Passed: 5d996f45-9f16-4b34-8c95-8c28611b7885.dat.png - Actual: noise, Watson Predicted: noise (0.992314)
# Passed: 392590c2-b0a5-411e-906b-cf03078d939e.dat.png - Actual: noise, Watson Predicted: noise (0.992261)
# Passed: 325b4bbe-75ad-40ec-aa77-1d8a48ed3077.dat.png - Actual: noise, Watson Predicted: noise (0.992807)
# Passed: a90d3033-3095-4fc1-b222-3a275f24a91d.dat.png - Actual: noise, Watson Predicted: noise (0.992183)
# Passed: 19767257-c4df-4e3e-849b-1554917d7e84.dat.png - Actual: noise, Watson Predicted: noise (0.992903)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_noise.zip... this may take a while.
# Passed: 917d19a6-5a48-43d7-ad70-73b4c42599e7.dat.png - Actual: noise, Watson Predicted: noise (0.99228)
# Passed: b82087b8-a98a-44ac-b703-da87b5406e15.dat.png - Actual: noise, Watson Predicted: noise (0.992928)
# Passed: 7fa4489a-4c79-4995-ab51-dc7f1728ee5a.dat.png - Actual: noise, Watson Predicted: noise (0.9929)
# Passed: 63ee933e-ac85-48f0-a1f4-5490f3135890.dat.png - Actual: noise, Watson Predicted: noise (0.992592)
# Passed: 95fd0e6c-8226-4ad4-a6e8-a57ae13fb808.dat.png - Actual: noise, Watson Predicted: noise (0.992714)
# Passed: 82b5fe95-5bce-49ab-86f7-6b0ad282fe34.dat.png - Actual: noise, Watson Predicted: noise (0.992289)
# Passed: da33af1c-41cb-433b-ad39-6a93ecbf5073.dat.png - Actual: noise, Watson Predicted: noise (0.992449)
# Passed: 4316179a-f317-4814-8bc9-caed31cd17dd.dat.png - Actual: noise, Watson Predicted: noise (0.99281)
# Passed: 9b53dd1d-a3ec-4dc2-b55a-489083884478.dat.png - Actual: noise, Watson Predicted: noise (0.992064)
# Passed: f9dc4629-7a34-46af-bcaf-a5549c7351bb.dat.png - Actual: noise, Watson Predicted: noise (0.99276)
# Passed: e8c790cb-582e-461b-88e9-e5a44869ff03.dat.png - Actual: noise, Watson Predicted: noise (0.992565)
# Passed: 7ef547c4-3068-408a-8aa8-e4b68fce79fa.dat.png - Actual: noise, Watson Predicted: noise (0.992443)
# Passed: be850466-db91-49ec-a9c3-526b9cbf4896.dat.png - Actual: noise, Watson Predicted: noise (0.992647)
# Passed: 86ccbddf-01c6-41cd-b40d-9118decc0626.dat.png - Actual: noise, Watson Predicted: noise (0.992748)
# Passed: 43e1e261-39d3-4311-8ec0-4bfe665d82c9.dat.png - Actual: noise, Watson Predicted: noise (0.992914)
# Test Score: 100% (15 of 15 Passed)
# Tested 15 images in 0.133333333333 minutes
# Running test (15 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_noise.zip... this may take a while.
# Passed: 44e6f04f-6845-411d-96fc-43626a82a350.dat.png - Actual: noise, Watson Predicted: noise (0.99195)
# Passed: a3d0d233-c944-44df-88f7-c9de0242913d.dat.png - Actual: noise, Watson Predicted: noise (0.992143)
# Passed: ccafad1c-2857-466d-a6ed-8fde8e754896.dat.png - Actual: noise, Watson Predicted: noise (0.992672)
# Passed: 7cbefd4b-bc13-44fa-9a76-a92d65509b4b.dat.png - Actual: noise, Watson Predicted: noise (0.992831)
# Passed: de8a1384-aa55-40fe-a8c0-df7634063809.dat.png - Actual: noise, Watson Predicted: noise (0.99252)
# Passed: 62dee652-6796-4cdd-80b4-cd05f3fe1382.dat.png - Actual: noise, Watson Predicted: noise (0.992645)
# Passed: d9559bfc-efa1-487d-a239-74b1a542e334.dat.png - Actual: noise, Watson Predicted: noise (0.992147)
# Passed: 382791f2-1a90-4b2c-ad17-e1f0fdebb6d5.dat.png - Actual: noise, Watson Predicted: noise (0.992411)
# Passed: 55dd42c1-f566-4603-9d24-b3593d23eb63.dat.png - Actual: noise, Watson Predicted: noise (0.992828)
# Passed: 99858525-2042-4af6-b698-472b1913b029.dat.png - Actual: noise, Watson Predicted: noise (0.992565)
# Passed: 84b5e2ad-a003-42ee-8bf2-ea6b526068d0.dat.png - Actual: noise, Watson Predicted: noise (0.99284)
# ...
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_4_narrowbanddrd.zip... this may take a while.
# Failed: f082ab21-57d7-4342-a579-1e8c6db2db3d.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.672403)
# Failed: db414c71-afc8-4ed6-aee6-b2721f37b780.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.574888)
# Passed: 85e80379-0f91-4392-bc67-f37bceb0dc6c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.907567)
# Failed: c9ca1316-2463-4ab0-90fa-74ec0da5be63.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.762254)
# Failed: ce5b7bba-e29e-470e-b0e5-40c47f0d57aa.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.747257)
# Passed: 27aa16e2-9391-4af1-a52e-313c00f0a45d.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.493087)
# Passed: 469f5453-2e4c-461e-a9a4-ffdac2b88b17.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.785738)
# Failed: 23481689-8341-4897-8822-e5c6de553b48.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.726416)
# Passed: 9ce5ec24-ba60-43d7-ab24-2e343076f770.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.632137)
# Passed: acaabc27-e67f-409e-8322-4de5f5bad8aa.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.555412)
# Failed: d2b60a58-aab2-48f1-94dc-e9606836d48f.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.932926)
# Failed: 78666cb4-120c-48c9-b0a0-a1bf0ac0a867.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.502569)
# Failed: 7989b06e-6266-4020-a7e2-1d9573f8bec0.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.525472)
# Passed: 97d32e04-24ea-4a92-991e-c8e698b6e4ee.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.85734)
# Passed: 732e9de7-cd76-41b6-bb43-b18fcdc22fee.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.793898)
# Failed: f9af7405-bce6-4f06-bd65-d65641df2ed3.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.738739)
# Failed: 458c0dfc-d8dd-4541-aa71-f9a3946c8680.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.768787)
# Passed: 7e631737-1561-4358-85c3-fb2ca51adefc.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.921163)
# Passed: ba536566-0d7e-4552-9474-5ceb6d4fc10f.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.839133)
# Passed: 23180343-cc97-4427-b90b-d1fdb5056797.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.641437)
# Test Score: 50% (10 of 20 Passed)
# Tested 20 images in 0.133333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_5_narrowbanddrd.zip... this may take a while.
# Passed: 7e44a48d-d3bf-43ae-99d9-de09f1a53dc8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.642564)
# Passed: faa9cbd9-484d-4d80-a182-d71d4f4cc55c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.706855)
# Failed: 798e20b9-c126-4ecd-a6ee-dee895d14d44.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.473079)
# Passed: 3db5cd24-665d-455b-98ba-71441045169d.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.865085)
# Passed: 52cf2853-2637-438a-85b0-e7bee90a61df.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.666838)
# Failed: b31d9dec-5659-4c9d-8094-3570cb94c9c5.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.466519)
# Failed: 0a052828-09cc-4a64-abde-a5a8e2843383.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.827005)
# Passed: ba85e428-5c8b-44a5-ab42-c0130261b531.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.877111)
# Passed: f54b0993-e0cd-43f7-a10a-92a88f401155.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.684359)
# Passed: 66090ae3-a553-4f7c-9b4a-bee47bddbfae.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.916692)
# Passed: 7f565c9e-cc3d-4936-85ee-7f8702806a4b.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.853711)
# Passed: efc2b4d3-fd30-40c3-8cfb-eb12ef2f153e.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.555625)
# Passed: aa7fcc4b-9194-445b-a6ea-58b5c96ce269.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.578543)
# Failed: b1b3ebe8-f39f-4c03-b258-28902e1d0ca6.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.541309)
# Failed: ff5c88bd-56c3-473e-8712-ae5dc36ab1ad.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.707942)
# Passed: fb63ee20-74e7-420b-ac63-cd221381b256.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.886059)
# Failed: b6d04876-a03a-46a2-af7e-5129810c7f04.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.519072)
# Failed: c7b988e5-023f-4e24-8195-95dbab13634a.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.558103)
# Passed: f7349332-f9b8-485a-9050-f3cba70ae643.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.779747)
# Passed: d8cf4624-fa1f-4deb-b233-07917403d9c8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.880787)
# Test Score: 65% (13 of 20 Passed)
# Tested 20 images in 0.116666666667 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_6_narrowbanddrd.zip... this may take a while.
# Passed: 59631170-32e0-4bc8-82e6-ef9993c0d161.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.552104)
# Passed: c0651aa4-db03-4a02-9491-cabf55039d2d.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.915354)
# Failed: 2fdf9595-bf35-4e61-ba17-9053e8c55fdc.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.834726)
# Failed: 81eb19c4-2b52-4c0f-bcfe-c607161fc4ef.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.568558)
# Failed: ea7dd5e0-6e75-4509-a017-cccdefb08c07.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.705887)
# Passed: 78a61f67-74a7-4ea6-9c3b-522e9e7b91bb.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.658195)
# Passed: be770123-f10c-4483-b96b-45617c51a9e8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.801975)
# Failed: c5ff6efc-91fb-4038-9d46-d50a4275a42a.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.900645)
# Passed: 0829926f-dc27-4c00-80fd-968a7ea558ca.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.711576)
# Passed: ae394633-d37f-4311-ac27-845b8674042e.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.915969)
# Passed: a59262d9-3eeb-4e22-8c5c-514daf6fb77f.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.595684)
# Passed: 7280145c-d5bb-45a0-8933-c24caf2aedb8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.724317)
# Passed: d7656f9e-e389-4583-a326-21e584e153cd.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.861126)
# Failed: 407461e9-f1c5-4eed-8e14-7a0c7acbc748.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.572739)
# Passed: e580cdae-bf33-4167-b5ec-74df272fca86.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.831459)
# Passed: a6a3a120-abf1-49b4-9d92-2b9671a40589.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.909313)
# Failed: dac2a874-0206-4350-8637-119aa69f7ed7.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.592415)
# Passed: a2abe937-168b-4612-b07a-5053d6b28825.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.892167)
# Passed: 1677993d-7507-433e-9215-10bb7da93f69.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.744008)
# Failed: 1e433c9b-9dfa-4da7-b1da-c8dd64c03e36.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.476165)
# Test Score: 65% (13 of 20 Passed)
# Tested 20 images in 0.183333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_7_narrowbanddrd.zip... this may take a while.
# Passed: a5eca1b3-e131-4985-a285-ae96597d67d8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.796847)
# Failed: 8d5a7a65-e9f2-4a33-b02c-d8b89c97739f.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.569522)
# Passed: 8d1dce92-aab0-44bc-869f-8b997fe32423.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.787478)
# Passed: 379d1fb1-ae7c-4662-b304-aae595d88f4d.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.815641)
# Passed: b1f2b409-13be-473f-9243-bec2afe29d58.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.766852)
# Passed: 31efa14b-cb36-4ff7-ac36-6fba12b7f0df.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.589381)
# Passed: e69bc753-86fb-48cd-aac8-6304b2aaa6e1.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.920954)
# Failed: 98e5e791-16ba-4f44-964b-ae40a377502c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.820517)
# Passed: ab75db8a-6c3e-4ef0-b686-1a88f3bbcbb0.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.467231)
# Passed: 10aa3e9a-a2a6-4544-8c05-3355bf8d6546.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.869346)
# Passed: b308a947-3181-4dcd-9b81-88d0d19ad8b2.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.579326)
# Failed: 1d85e906-cade-4c18-b2e7-c626f9f68435.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.852691)
# Passed: 46a5343e-d611-4530-8582-f6861f2b3c01.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.862455)
# Passed: bf69fc6f-e65b-4708-8dc5-963cbac7322c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.871279)
# Passed: 52420254-5068-4de8-aa1d-9c4ac6aa4034.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.669373)
# Passed: cd1ab8b3-1699-4a1a-af11-7531d4574040.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.845549)
# Passed: 5b8e91a9-b3f8-48f6-b8aa-5fcf9b54a167.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.840564)
# Failed: 3d21961a-5cbf-4083-ab8d-46e0d5dcd956.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.76536)
# Passed: b7098eb7-cfd5-43e3-abfe-47f2ad90e658.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.71948)
# Failed: 53a4940c-d810-4c6c-89eb-a7f9b59de453.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.558449)
# Test Score: 75% (15 of 20 Passed)
# Tested 20 images in 0.133333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_8_narrowbanddrd.zip... this may take a while.
# Passed: 2af112c7-6f05-4490-9005-bc5d7dc750e2.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.544959)
# Failed: 08e4b48f-8410-4c6c-be9c-4b5ad381eed9.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.692894)
# Failed: 82f06118-2882-47bc-8313-48f18a536d56.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.811352)
# Failed: e3e9d859-64e1-4030-b188-80f9a80a52db.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.805039)
# Failed: 80673aad-2d9f-4651-a35e-7f39afd65226.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.925062)
# Failed: 3254d849-6c03-4396-88f1-2ab26fcde8d6.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.659475)
# Failed: 6accb8ae-5647-4fde-9c53-54baabed9c73.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.577165)
# Failed: a04292d1-b797-4488-8c42-685bad8a7351.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.760161)
# Failed: fd8c988b-6421-4f74-97b0-1ec77295680b.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.820242)
# Passed: 3124da89-f0b1-4f54-a1f8-1870b8534fe2.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.624068)
# Passed: 01cbdc8a-3ee0-4a54-b82d-7b1b61712b79.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.53578)
# Failed: 241a37f8-f832-4287-9889-3ade4cb086d1.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.895903)
# Passed: 4952ff1f-daff-425c-bbb8-de0eb3e818f5.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.883092)
# Passed: e428eaa8-458c-41d2-8f8e-881f47049627.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.869435)
# Failed: d9385877-e633-4278-ba95-7c8ba82854b6.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.510546)
# Passed: 4a34a913-f71a-4bf0-81b5-b45fa2632768.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.521541)
# Failed: 781b4358-db5d-4be9-941f-3458412e4a95.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.719018)
# Failed: 684df170-a8da-42d1-b6c7-ea245c0c795c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.568574)
# Passed: fe547600-8bf9-4830-8ecf-a4ee6f2ebf45.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.750257)
# Failed: 0a0ae231-d3b5-470d-83fa-23861c19f5cd.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.634961)
# Test Score: 35% (7 of 20 Passed)
# Tested 20 images in 0.133333333333 minutes
# Running test (20 images) for /gpfs/fs01/user/s18f-42b3305d048694-5fca760d00b1/notebook/work/Machine_Contact_Enterprise_SETI/zippedPngs3/testset_9_narrowbanddrd.zip... this may take a while.
# Passed: 7cb77b18-575f-4040-a954-8f1640f2bdab.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.921833)
# Passed: f1b5d4ab-ae4e-4ca0-832d-c14fdd03894c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.518075)
# Passed: 647b6dd6-a026-4f96-b431-35b1c47129da.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.532797)
# Failed: 70a7638f-9d98-4090-8a17-c6adbe5f6055.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.643725)
# Passed: 105b2236-6b4b-4d13-a43b-fe993e9214f2.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.626583)
# Passed: 3c7a3844-db7e-449d-8058-01a853d4188c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.837265)
# Failed: e5764e09-77fd-4499-bd20-d0209484626a.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.488076)
# Passed: c0901a41-3c0d-496e-835b-81158dce8036.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.925916)
# Failed: cb81e039-690a-4e43-99eb-c81311cdd0f2.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.786911)
# Passed: 14df76fd-e0f4-44d6-aebf-cafad2a8a7ab.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.818475)
# Passed: d12addbc-50db-47c9-97f1-40f75290a88a.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.899352)
# Failed: d4cf7d09-18dd-4a26-b4b3-0d38e3ee3a8f.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.785686)
# Failed: 43d75330-ca2d-4c2c-b96d-d36c8c8f628b.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.621612)
# Passed: 8a312ce1-9c13-4c0b-a94a-4aa6dc772c09.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.678447)
# Passed: bc5eee51-1690-4226-9557-b7477090b88b.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.894072)
# Failed: c28feed7-8b6f-44c2-8b39-9b4ba7f663f7.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.646091)
# Passed: 3b29338f-76b4-45cb-80cc-837cc0e09c8c.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.672104)
# Passed: 3627b667-9943-4761-b4a7-9c52ffcb6db6.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.891159)
# Failed: 7545cafa-97ba-4dc2-9c2c-37f543e71312.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowband (0.682492)
# Passed: b3b57da2-539c-4b20-a041-dead2113dba8.dat.png - Actual: narrowbanddrd, Watson Predicted: narrowbanddrd (0.759834)
# Test Score: 65% (13 of 20 Passed)
# Tested 20 images in 0.116666666667 minutes
# DONE.

# %%
import pickle
pickle.dump(results_group_by_class, open(mydatafolder + '/' + "watson_results2.pickle", "w"))

# %%
#TODO number results
watson_results = pickle.load(open(mydatafolder + '/' + "watson_results.pickle2","r"))
# reorganize the watson_results dictionary to extract
# a list of [true_class, [scores], estimated_class] and
# use these for measuring our model's performance

class_scores = []
for k in watson_results.keys():
    class_scores += zip(watson_results[k]['uuid'], watson_results[k]['signal_classification'], watson_results[k]['scores'], watson_results[k]['watson_class'] )

# %%
class_scores[100]
# Out:
# (u'4e020e83-5c2e-464a-a9d0-915c8f5db8d4',
#  'squiggle',
#  [0.0711978, 0.0319435, 0.0674044, 0.956612],
#  u'squiggle')

# %%
from sklearn.metrics import classification_report
import sklearn

y_train = [x[1] for x in class_scores]
y_pred = [x[3] for x in class_scores]
y_prob = [x[2] for x in class_scores]
#we normalize the Watson score values to 1 in order to use them in the log_loss calculation even though the Watson VR scores are not true class prediction probabilities
y_prob = map(lambda x: (x, sum(x)), y_prob)
y_prob = map(lambda x: [y / x[1] for y in x[0]], y_prob)

print sklearn.metrics.classification_report(y_train,y_pred)
print sklearn.metrics.confusion_matrix(y_train,y_pred)
print("Classification accuracy: %0.6f" % sklearn.metrics.accuracy_score(y_train,y_pred) )
print("Log Loss: %0.6f" % sklearn.metrics.log_loss(y_train,y_prob) )
# Out:
#              precision    recall  f1-score   support
#
#  narrowband       0.64      0.61      0.63       200
# narrowbanddrd       0.62      0.66      0.64       200
#       noise       0.99      1.00      0.99       194
#    squiggle       1.00      0.97      0.99       200
#
# avg / total       0.81      0.81      0.81       794
#
# [[123  77   0   0]
#  [ 68 132   0   0]
#  [  0   0 194   0]
#  [  0   3   2 195]]
# Classification accuracy: 0.811083
# Log Loss: 0.494020

# %% [markdown]
# # Generate CSV file for Scoreboard
#
# #### NOTE: This uses the PNG files created in the Step 3 notebook, which only contain the BASIC4 data set. The code challenge and hackathon will be based on the Primary Data Set which contains 7 signal classes

# %%
import csv
#TODO number scores
my_output_results = mydatafolder + '/' + 'watson_scores2.csv'
with open(my_output_results, 'w') as csvfile:
    fwriter = csv.writer(csvfile, delimiter=',')
    for row in class_scores:
        fwriter.writerow([row[0]] + row[2])

# %%
#print out the first 10 lines just to show it makes sense

# !cat $mydatafolder/watson_scores2.csv

# %%
credentials = {
  'auth_uri':'',
  'global_account_auth_uri':'',
  'username':'xx',
  'password':"xx",
  'auth_url':'https://identity.open.softlayer.com',
  'project':'xx',
  'project_id':'xx',
  'region':'dallas',
  'user_id':'xx',
  'domain_id':'xx',
  'domain_name':'xx',
  'tenantId':'xx'
}

import swiftclient.client as swiftclient

conn = swiftclient.Connection(
    key=credentials['password'],
    authurl=credentials['auth_url']+"/v3",
    auth_version='3',
    os_options={
        "project_id": credentials['project_id'],
        "user_id": credentials['user_id'],
        "region_name": credentials['region']})

myObjectStorageContainer = 'hackathon_scores'  
conn_seti_data.post_container(myObjectStorageContainer)  #creates a new container in your object storage

#classification_results_file = 'my_team_name_data_folder/results/my_final_testset_classes.csv'
etag = conn.put_object(myObjectStorageContainer, 'watson_scores.csv', open(my_output_results).read())
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-29-4ab62b24dae3> in <module>()
#      26
#      27 myObjectStorageContainer = 'hackathon_scores'
# ---> 28 conn_seti_data.post_container(myObjectStorageContainer)  #creates a new container in your object storage
#      29
#      30 #classification_results_file = 'my_team_name_data_folder/results/my_final_testset_classes.csv'
#
# NameError: name 'conn_seti_data' is not defined

# %%
# rm -rf Machine_Contact_Enterprise_SETI/cleanPngs/

# %%
# mv Machine_Contact_Enterprise_SETI/png Machine_Contact_Enterprise_SETI/cleanPngs

# %%
# ls Machine_Contact_Enterprise_SETI/cleanPngs

# %%
# cp --help
